# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
openai_api_key = os.getenv('OPENAI_API_KEY')
gemini_api_key = os.getenv('GEMINI_API_KEY')
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI
openai = OpenAI()

# %%
messages = [{"role": "user", "content": "What is 2+2?"}]

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If twelve workers can build twelve machines in twelve hours, how many hours would it take six workers to build six machines?

# %%
messages = [{"role": "user", "content": question}]

# %%
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step.
#
# ### Given:
# - 12 workers build 12 machines in 12 hours.
#
# ### Objective:
# - Find how many hours 6 workers take to build 6 machines.
#
# ---
#
# ### Step 1: Find the rate of work per worker
#
# If 12 workers build 12 machines in 12 hours, what is the rate at which one worker builds machines?
#
# - Total machine-hours = 12 machines × 12 hours = 144 machine-hours.
# - Total worker-hours = 12 workers × 12 hours = 144 worker-hours.
#
# Since 144 worker-hours produce 12 machines:
#
# - One worker-hour produces \(\frac{12}{144} = \frac{1}{12}\) machines.
# - Thus, one worker builds \(\frac{1}{12}\) of a machine per hour.
#
# ---
#
# ### Step 2: Find how long 6 workers take to build 6 machines
#
# - Rate of 6 workers = \(6 \times \frac{1}{12} = \frac{6}{12} = \frac{1}{2}\) machines per hour.
# - To build 6 machines at a rate of \(\frac{1}{2}\) machines/hour:
#   \[
#   \text{Time} = \frac{\text{Work}}{\text{Rate}} = \frac{6}{\frac{1}{2}} = 6 \times 2 = 12 \text{ hours}
#   \]
#
# ---
#
# ### **Answer:**
#
# It would take **12 hours** for 6 workers to build 6 machines.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step.
#
# ### Given:
# - 12 workers build 12 machines in 12 hours.
#
# ### Objective:
# - Find how many hours 6 workers take to build 6 machines.
#
# ---
#
# ### Step 1: Find the rate of work per worker
#
# If 12 workers build 12 machines in 12 hours, what is the rate at which one worker builds machines?
#
# - Total machine-hours = 12 machines × 12 hours = 144 machine-hours.
# - Total worker-hours = 12 workers × 12 hours = 144 worker-hours.
#
# Since 144 worker-hours produce 12 machines:
#
# - One worker-hour produces \(\frac{12}{144} = \frac{1}{12}\) machines.
# - Thus, one worker builds \(\frac{1}{12}\) of a machine per hour.
#
# ---
#
# ### Step 2: Find how long 6 workers take to build 6 machines
#
# - Rate of 6 workers = \(6 \times \frac{1}{12} = \frac{6}{12} = \frac{1}{2}\) machines per hour.
# - To build 6 machines at a rate of \(\frac{1}{2}\) machines/hour:
#   \[
#   \text{Time} = \frac{\text{Work}}{\text{Rate}} = \frac{6}{\frac{1}{2}} = 6 \times 2 = 12 \text{ hours}
#   \]
#
# ---
#
# ### **Answer:**
#
# It would take **12 hours** for 6 workers to build 6 machines.
