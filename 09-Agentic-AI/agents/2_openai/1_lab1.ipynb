# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4.1-nano")

# %%
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent break up with the chatbot?
#
# Because every time they tried to "connect," it just kept giving them the cold "server" shoulder!

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
