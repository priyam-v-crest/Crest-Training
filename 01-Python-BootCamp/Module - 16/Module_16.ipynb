# %%
from PIL import Image

# %%
mac = Image.open('example.jpg')
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x376>

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.size
# Out:
# (250, 376)

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %% [markdown]
# ## Cropping

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
pc = mac.crop((60, 25, 183,280))
pc
# Out:
# <PIL.Image.Image image mode=RGB size=123x255>

# %%
mac.paste(im=pc, box=(0,0))
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x376>

# %%
mac.resize((500,700))
# Out:
# <PIL.Image.Image image mode=RGB size=500x700>

# %%
mac.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGB size=250x376>
